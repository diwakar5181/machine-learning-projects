# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Objectives:-
# 1. Read Travel data as csv
# 2. Perform data cleaning
# 3. Perform feature engineering and encoding
# 4. Train, test, split data
# 5. Train AdaboostClassifier and other multiple models for comparison
# 6. Print and review performance metrics (accuracy_score, precision_score, recall_score, f1_score, roc_auc_score) for both test and training data for all teh models
# 7. Fine tune model by passing hyperparameters using RandomizedSearchCV for Random Forrest and Ada Boost models
# 8. Find best params
# 9. Rerun models with the best parameters
# 10. Print and review performance metrics (accuracy_score, precision_score, recall_score, f1_score, roc_auc_score) for both test and training data
# 11. Plot AUC for Adaboost Classifier

# %%
df = pd.read_csv('../data/raw/Travel.csv')

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0         Deluxe                    3.0        Single            1.0
# 1         Deluxe                    4.0      Divorced            2.0
# 2          Basic                    3.0        Single            7.0
# 3          Basic                    3.0      Divorced            2.0
# 4          Basic                    4.0      Divorced            1.0
#
#    Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0         1                       2       1                       0.0
# 1         0                       3       1                       2.0
# 2         1                       3       0                       0.0
# 3         1                       5       1                       1.0
# 4         0                       5       1                       0.0
#
#   Designation  MonthlyIncome
# 0     Manager        20993.0
# 1     Manager        20130.0
# 2   Executive        17090.0
# 3   Executive        17909.0
# 4   Executive        18468.0

# %% [markdown]
# ### Data Cleaning
# 1. Handling missing values
# 2. Handling duplicates
# 3. Check data type

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male       2916
# Female     1817
# Fe Male     155
# Name: count, dtype: int64

# %%
df['Gender'] = df['Gender'].apply(lambda x: 'Female' if x == 'Fe Male' else x )
df['Gender'].value_counts()
# Out:
# Gender
# Male      2916
# Female    1972
# Name: count, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: count, dtype: int64

# %%
df['MaritalStatus'] = df['MaritalStatus'].apply(lambda x: 'Unmarried' if x == 'Single' else x)
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married      2340
# Unmarried    1598
# Divorced      950
# Name: count, dtype: int64

# %%
features_na = [features for features in df.columns if df[features].isnull().sum() >= 1]
for feature in features_na:
    print(feature, np.round(df[feature].isnull().mean() *100,5 ), '% missing value')
# Out:
# Age 4.62357 % missing value
# TypeofContact 0.51146 % missing value
# DurationOfPitch 5.13502 % missing value
# NumberOfFollowups 0.92062 % missing value
# PreferredPropertyStar 0.53191 % missing value
# NumberOfTrips 2.86416 % missing value
# NumberOfChildrenVisiting 1.35025 % missing value
# MonthlyIncome 4.76678 % missing value

# %%
df[features_na].describe()
# Out:
#                Age  DurationOfPitch  NumberOfFollowups  PreferredPropertyStar  \
# count  4662.000000      4637.000000        4843.000000            4862.000000
# mean     37.622265        15.490835           3.708445               3.581037
# std       9.316387         8.519643           1.002509               0.798009
# min      18.000000         5.000000           1.000000               3.000000
# 25%      31.000000         9.000000           3.000000               3.000000
# 50%      36.000000        13.000000           4.000000               3.000000
# 75%      44.000000        20.000000           4.000000               4.000000
# max      61.000000       127.000000           6.000000               5.000000
#
#        NumberOfTrips  NumberOfChildrenVisiting  MonthlyIncome
# count    4748.000000               4822.000000    4655.000000
# mean        3.236521                  1.187267   23619.853491
# std         1.849019                  0.857861    5380.698361
# min         1.000000                  0.000000    1000.000000
# 25%         2.000000                  1.000000   20346.000000
# 50%         3.000000                  1.000000   22347.000000
# 75%         4.000000                  2.000000   25571.000000
# max        22.000000                  3.000000   98678.000000

# %%
# replace null values in categorical columns with Mode and numerical columns with Median
df.fillna({'Age': df['Age'].median()}, inplace=True)
df.fillna({'DurationOfPitch': df['DurationOfPitch'].median()}, inplace=True)
df.fillna({'NumberOfTrips': df['NumberOfTrips'].median()}, inplace=True)
df.fillna({'MonthlyIncome': df['MonthlyIncome'].median()}, inplace=True)

df.fillna({'TypeofContact': df['TypeofContact'].mode()[0]}, inplace=True)
df.fillna({'NumberOfFollowups': df['NumberOfFollowups'].mode()[0]}, inplace=True)
df.fillna({'PreferredPropertyStar': df['PreferredPropertyStar'].mode()[0]}, inplace=True)
df.fillna({'NumberOfChildrenVisiting': df['NumberOfChildrenVisiting'].mode()[0]}, inplace=True)

df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %%
# drop CustomerID as it has no influence on the dependent feature

df.drop('CustomerID', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['ProdTaken', 'Age', 'TypeofContact', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='str')

# %% [markdown]
# ### Feature Engineering

# %%
# combine person and children visiting column
df['TotalVisiting'] = df['NumberOfPersonVisiting'] + df['NumberOfChildrenVisiting']
df.drop(['NumberOfChildrenVisiting', 'NumberOfPersonVisiting'], axis=1, inplace=True)

# %%
X,y = df.drop('ProdTaken', axis=1), df['ProdTaken']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# Transform columns
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

cat_feat = X.select_dtypes(include='str').columns
num_feat = X.select_dtypes(exclude='str').columns

num_tranformer = StandardScaler()
cat_transformer = OneHotEncoder(drop='first')

preprocessor = ColumnTransformer([('OneHotEncoder', cat_transformer, cat_feat), ('StandardScaler', num_tranformer, num_feat)])

# %%
# transform only on test dataset to prevent data leakage
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %% [markdown]
# ### Multiple Classifier models Implementation including Adaboost

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay, precision_score, recall_score, f1_score, roc_auc_score, roc_curve

models = {'Random Forest Classifier': RandomForestClassifier(),
          'Logistic Regression': LogisticRegression(),
          'Decision Tree Regressor': DecisionTreeRegressor(),
          'AdaBoostClassifier': AdaBoostClassifier()}

for k, v in models.items():
    model = v
    model.fit(X_train, y_train)

    # make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # training model performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred)
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted')
    model_train_precision = precision_score(y_train, y_train_pred)
    model_train_recall = recall_score(y_train, y_train_pred)
    model_train_roc_auc_score = roc_auc_score(y_train, y_train_pred)

    # test model performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred)
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted')
    model_test_precision = precision_score(y_test, y_test_pred)
    model_test_recall = recall_score(y_test, y_test_pred)
    model_test_roc_auc_score = roc_auc_score(y_test, y_test_pred)
    
    print('==============================================')
    print(k,':- Metrics')
    print('==============================================')
    print('Train Model Performance Metrics ')
    print(f'Accuracy:- {model_train_accuracy}')
    print(f'F1:- {model_train_f1}')
    print(f'Precison:- {model_train_precision}')
    print(f'Reacll:- {model_train_recall}')
    print(f'Roc AUC Score:- {model_train_roc_auc_score}')

    print('-----------------------------------------------')

    print('Test Model Performance Metrics ')
    print(f'Accuracy:- {model_test_accuracy}')
    print(f'F1:- {model_test_f1}')
    print(f'Precison:- {model_test_precision}')
    print(f'Reacll:- {model_test_recall}')
    print(f'Roc AUC Score:- {model_test_roc_auc_score}')
# Out:
# ==============================================
# Random Forest Classifier :- Metrics
# ==============================================
# Train Model Performance Metrics
# Accuracy:- 1.0
# F1:- 1.0
# Precison:- 1.0
# Reacll:- 1.0
# Roc AUC Score:- 1.0
# -----------------------------------------------
# Test Model Performance Metrics
# Accuracy:- 0.9294478527607362
# F1:- 0.9238387055575747
# Precison:- 0.9765625
# Reacll:- 0.6544502617801047
# Roc AUC Score:- 0.825319158844309
# ==============================================
# Logistic Regression :- Metrics
# ==============================================
# Train Model Performance Metrics
# Accuracy:- 0.8460358056265984
# F1:- 0.8202118738880438
# Precison:- 0.7015873015873015
# Reacll:- 0.30315500685871055
# Roc AUC Score:- 0.6368022755136056
# -----------------------------------------------
# Test Model Performance Metrics
# Accuracy:- 0.83640081799591
# F1:- 0.8086633047343356
# Precison:- 0.691358024691358
# Reacll:- 0.2931937172774869
# Roc AUC Score:- 0.630713758257549
# ==============================================
# Decision Tree Regressor :- Metrics
# ==============================================
# Train Model Performance Metrics
# Accuracy:- 1.0
# F1:- 1.0
# Precison:- 1.0
# Reacll:- 1.0
# Roc AUC Score:- 1.0
# -----------------------------------------------
# Test Model Performance Metrics
# Accuracy:- 0.9202453987730062
# F1:- 0.9185425755354569
# Precison:- 0.8304093567251462
# Reacll:- 0.743455497382199
# Roc AUC Score:- 0.853303352248914
# ==============================================
# AdaBoostClassifier :- Metrics
# ==============================================
# Train Model Performance Metrics
# Accuracy:- 0.8478260869565217
# F1:- 0.8146439190446891
# Precison:- 0.7815126050420168
# Reacll:- 0.2551440329218107
# Roc AUC Score:- 0.6193984861245332
# -----------------------------------------------
# Test Model Performance Metrics
# Accuracy:- 0.8353783231083844
# F1:- 0.7987434557925993
# Precison:- 0.75
# Reacll:- 0.2356020942408377
# Roc AUC Score:- 0.6082711868917022

# %%
# Hyperparameter tuning for Random Forest and Adaboost

params_rfc = {'max_depth': [None, 5, 8, 10, 15],
          'max_features': ['auto', 5, 7, 8],
          'min_samples_split': [2, 8, 15, 20],
          'n_estimators': [100, 200, 500, 1000]}
params_adaboost = {'n_estimators': [50, 60, 70, 80, 90]}

# %%
from sklearn.model_selection import RandomizedSearchCV

random_cv_models = [('RF', RandomForestClassifier(), params_rfc), ('Adaboost', AdaBoostClassifier(), params_adaboost)]
model_best_param = {}
for name, model, param in random_cv_models:
    random = RandomizedSearchCV(estimator=model, param_distributions=param, n_iter=100, cv=3, verbose=2, n_jobs= -1 )
    random.fit(X_train, y_train)
    model_best_param[name] = random.best_params_

for name in model_best_param:
    print('==========================')
    print(f'--------- Model {name} best params -----------')
    print(model_best_param[name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.4s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.4s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.4s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.3s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.3s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=500; total time=   3.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=500; total time=   3.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=500; total time=   3.3s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   3.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   3.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   3.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.6s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.7s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.5s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=1000; total time=   7.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=1000; total time=   7.8s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=1000; total time=   6.4s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=1000; total time=   8.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=1000; total time=   7.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=1000; total time=   8.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=1000; total time=   8.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.6s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.6s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.6s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=500; total time=   4.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=500; total time=   4.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=500; total time=   4.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=200; total time=   1.6s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=200; total time=   1.6s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=200; total time=   1.7s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.1s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_depth=8, max_features=7, min_samples_split=8, n_estimators=500; total time=   4.6s
# [CV] END max_depth=8, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=8, max_features=7, min_samples_split=8, n_estimators=500; total time=   4.6s
# [CV] END max_depth=8, max_features=7, min_samples_split=8, n_estimators=500; total time=   4.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=1000; total time=  10.3s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=1000; total time=  10.4s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=1000; total time=  10.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=500; total time=   4.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=500; total time=   4.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=500; total time=   4.8s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=1000; total time=  10.5s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=1000; total time=  10.6s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=1000; total time=  10.8s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=1000; total time=  10.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=1000; total time=  11.1s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=1000; total time=  11.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.2s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.2s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=1000; total time=   8.9s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=1000; total time=   9.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=500; total time=   6.9s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=500; total time=   6.9s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=   4.1s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=   4.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=500; total time=   7.7s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=1000; total time=  10.3s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=   4.7s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=500; total time=   7.1s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=200; total time=   3.5s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=200; total time=   3.5s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=200; total time=   3.7s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=500; total time=   7.0s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=500; total time=   7.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=   9.8s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=  10.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=  10.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=100; total time=   1.9s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=100; total time=   1.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=100; total time=   1.8s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=1000; total time=  17.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=100; total time=   2.0s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=1000; total time=  17.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=100; total time=   2.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=1000; total time=  18.5s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=100; total time=   2.4s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=100; total time=   2.4s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=100; total time=   2.4s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=200; total time=   4.2s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=200; total time=   4.2s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=200; total time=   4.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=500; total time=   8.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=500; total time=   8.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=500; total time=   8.2s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=100; total time=   1.9s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=100; total time=   1.9s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=1000; total time=  18.3s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=100; total time=   1.9s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=1000; total time=  18.2s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=200; total time=   4.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=1000; total time=  18.8s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   2.8s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   2.8s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   3.4s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=200; total time=   5.2s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=200; total time=   5.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=200; total time=   5.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=1000; total time=  22.8s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=1000; total time=  22.9s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=1000; total time=  23.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=500; total time=  12.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=500; total time=  12.1s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=500; total time=  12.4s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=500; total time=  13.1s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=500; total time=  13.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=200; total time=   3.1s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=500; total time=  13.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=500; total time=  12.0s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=200; total time=   2.9s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=500; total time=  12.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=500; total time=  12.7s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=100; total time=   2.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   4.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=100; total time=   1.9s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=100; total time=   1.9s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   4.2s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=200; total time=   4.0s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=200; total time=   3.8s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=200; total time=   3.7s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=100; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=100; total time=   1.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=1000; total time=  22.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=1000; total time=  22.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=100; total time=   1.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=1000; total time=  22.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=200; total time=   3.0s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=100; total time=   1.6s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=   8.4s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=   8.4s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=   8.5s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=500; total time=   8.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=500; total time=   8.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=500; total time=   8.3s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=   6.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=1000; total time=  15.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=   6.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=1000; total time=  16.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=   7.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=1000; total time=  16.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=1000; total time=  14.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=1000; total time=  14.7s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=200; total time=   4.4s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=200; total time=   4.4s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=1000; total time=  15.3s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=200; total time=   4.4s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=100; total time=   2.1s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=100; total time=   2.2s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=500; total time=   9.2s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=500; total time=   9.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   3.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   3.1s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   3.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=500; total time=   9.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   5.8s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   5.8s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   5.7s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=500; total time=   6.3s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=500; total time=   6.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=1000; total time=  13.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=500; total time=   6.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=1000; total time=  13.5s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=1000; total time=  13.5s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=1000; total time=  10.6s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=1000; total time=  10.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=1000; total time=  10.2s
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] END ....................................n_estimators=50; total time=   0.5s
# [CV] END ....................................n_estimators=50; total time=   0.5s
# [CV] END ....................................n_estimators=50; total time=   0.5s
# [CV] END ....................................n_estimators=60; total time=   0.6s
# [CV] END ....................................n_estimators=60; total time=   0.6s
# [CV] END ....................................n_estimators=60; total time=   0.6s
# [CV] END ....................................n_estimators=70; total time=   0.7s
# [CV] END ....................................n_estimators=70; total time=   0.7s
# [CV] END ....................................n_estimators=70; total time=   0.7s
# [CV] END ....................................n_estimators=80; total time=   0.7s
# [CV] END ....................................n_estimators=80; total time=   0.7s
# [CV] END ....................................n_estimators=80; total time=   0.7s
# [CV] END ....................................n_estimators=90; total time=   0.6s
# [CV] END ....................................n_estimators=90; total time=   0.6s
# [CV] END ....................................n_estimators=90; total time=   0.6s
# ==========================
# --------- Model RF best params -----------
# {'n_estimators': 200, 'min_samples_split': 2, 'max_features': 8, 'max_depth': None}
# ==========================
# --------- Model Adaboost best params -----------
# {'n_estimators': 80}

# %%
# let's rexecute previously created Random Forrest and Adaboost Models with best params and review the prformance metrics


models = {'Random Forest Classifier': RandomForestClassifier(n_estimators=model_best_param['RF']['n_estimators'],
                                                              min_samples_split=model_best_param['RF']['min_samples_split'], 
                                                              max_features=model_best_param['RF']['max_features'], 
                                                              max_depth=model_best_param['RF']['max_depth'], n_jobs=-1),
          'Adaboost Classifier': AdaBoostClassifier(n_estimators=model_best_param['Adaboost']['n_estimators'])}

for k, v in models.items():
    model = v
    model.fit(X_train, y_train)

    # make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # training model performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred)
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted')
    model_train_precision = precision_score(y_train, y_train_pred)
    model_train_recall = recall_score(y_train, y_train_pred)
    model_train_roc_auc_score = roc_auc_score(y_train, y_train_pred)

    # test model performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred)
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted')
    model_test_precision = precision_score(y_test, y_test_pred)
    model_test_recall = recall_score(y_test, y_test_pred)
    model_test_roc_auc_score = roc_auc_score(y_test, y_test_pred)

    print('======================================')
    print(k,':- Metrics')
    print('Train Model Performance Metrics ')
    print(f'Accuracy:- {model_train_accuracy}')
    print(f'F1:- {model_train_f1}')
    print(f'Precison:- {model_train_precision}')
    print(f'Reacll:- {model_train_recall}')
    print(f'Roc AUC Score:- {model_train_roc_auc_score}')

    print('---------------------------------------')

    print('\n')

    print('Test Model Performance Metrics ')
    print(f'Accuracy:- {model_test_accuracy}')
    print(f'F1:- {model_test_f1}')
    print(f'Precison:- {model_test_precision}')
    print(f'Reacll:- {model_test_recall}')
    print(f'Roc AUC Score:- {model_test_roc_auc_score}')
# Out:
# ======================================
# Random Forest Classifier :- Metrics
# Train Model Performance Metrics
# Accuracy:- 1.0
# F1:- 1.0
# Precison:- 1.0
# Reacll:- 1.0
# Roc AUC Score:- 1.0
# ---------------------------------------
#
#
# Test Model Performance Metrics
# Accuracy:- 0.9314928425357873
# F1:- 0.9268880423581842
# Precison:- 0.9558823529411765
# Reacll:- 0.680628272251309
# Roc AUC Score:- 0.8365021920341679
# ======================================
# Adaboost Classifier :- Metrics
# Train Model Performance Metrics
# Accuracy:- 0.8465473145780051
# F1:- 0.8131954184297732
# Precison:- 0.7698744769874477
# Reacll:- 0.252400548696845
# Roc AUC Score:- 0.6175551941849519
# ---------------------------------------
#
#
# Test Model Performance Metrics
# Accuracy:- 0.83640081799591
# F1:- 0.797683978346618
# Precison:- 0.7818181818181819
# Reacll:- 0.225130890052356
# Roc AUC Score:- 0.6049415568432047

# %%
# let's plot Adaboost AUC

plt.figure()

auc_models = [{'label': 'Adaboost Classifier', 'model':AdaBoostClassifier(n_estimators=80), 'auc_score': 0.60}]

for algo in auc_models:
    model = algo['model']
    model.fit(X_train, y_train)

    fpr, tpr, threshold = roc_curve(y_test, model.predict_proba(X_test)[:,1])
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (algo['label'], algo['auc_score']))

# Custom settings for the plot 
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1-Specificity(False Positive Rate)')
plt.ylabel('Sensitivity(True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
