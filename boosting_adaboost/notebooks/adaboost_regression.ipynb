# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Objectives:-
# 1. Read car sales data as csv
# 2. Perform data cleaning by checking for nulls and dropping unwanted columns
# 3. Perform feature encoding using LabelEncoder, OneHotEncoder, and StandardScaler
# 4. Train, test, split data
# 5. Train multiple Regression models (AdaBoostRegressor, LinearRegression, Ridge, Lasso, RandomForestRegressor, KNeighborsRegressor, DecisionTreeRegressor)
# 6. Print and review performance metrics (r2_score, mean_absolute_error, mean_squared_error) for both test and training data
# 7. Take three models (AdaBoostRegressor, RandomForestRegressor, KNeighborsRegressor) and fine tune them by passing hyperparameters using RandomizedSearchCV
# 8. Find best params
# 9. Rerun AdaBoostRegressor, RandomForestRegressor and KNeighborsRegressor models with the best parameters
# 10. Print and review performance metrics (r2_score, mean_absolute_error, mean_squared_error) for both test and training data

# %%
df = pd.read_csv('../data/raw/cardekho_imputated.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15411 non-null  int64
#  1   car_name           15411 non-null  str
#  2   brand              15411 non-null  str
#  3   model              15411 non-null  str
#  4   vehicle_age        15411 non-null  int64
#  5   km_driven          15411 non-null  int64
#  6   seller_type        15411 non-null  str
#  7   fuel_type          15411 non-null  str
#  8   transmission_type  15411 non-null  str
#  9   mileage            15411 non-null  float64
#  10  engine             15411 non-null  int64
#  11  max_power          15411 non-null  float64
#  12  seats              15411 non-null  int64
#  13  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(6), str(6)
# memory usage: 1.6 MB

# %% [markdown]
# ### Data Cleaning

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
df.isnull().sum()
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
# out 0f drop car_name and brand and model let's drop 2 columns as it's repetitive infomration

df.drop(['brand', 'car_name'], axis=1, inplace=True)
df.head()
# Out:
#       model  vehicle_age  km_driven seller_type fuel_type transmission_type  \
# 0      Alto            9     120000  Individual    Petrol            Manual
# 1     Grand            5      20000  Individual    Petrol            Manual
# 2       i20           11      60000  Individual    Petrol            Manual
# 3      Alto            9      37000  Individual    Petrol            Manual
# 4  Ecosport            6      30000      Dealer    Diesel            Manual
#
#    mileage  engine  max_power  seats  selling_price
# 0    19.70     796      46.30      5         120000
# 1    18.90    1197      82.00      5         550000
# 2    17.00    1197      80.00      5         215000
# 3    20.92     998      67.10      5         226000
# 4    22.77    1498      98.59      5         570000

# %%
# split data into dependent and independent features
X, y = df.drop('selling_price', axis=1), df['selling_price']

# %% [markdown]
# ### Feature Encoding

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

label_encoder = LabelEncoder()
X['model'] = label_encoder.fit_transform(X['model'])

# %%
# Create Column transformer
from sklearn.compose import ColumnTransformer

num_feat = X.select_dtypes(exclude='str').columns
one_hot_columns = ['seller_type', 'fuel_type', 'transmission_type']

num_transformer = StandardScaler()
one_hot_transformer = OneHotEncoder(drop='first')

preprocessor = ColumnTransformer([("text_preprocess", one_hot_transformer, one_hot_columns),("num_preprocess", num_transformer, num_feat)],
                                  remainder='passthrough')

X = preprocessor.fit_transform(X)

# %%
# train, test, split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV

# %%
def evaluate_model(true_val, predicted_value):
    mse = mean_squared_error(true_val, predicted_value)
    mae = mean_absolute_error(true_val, predicted_value)
    r2 = r2_score(true_val, predicted_value)

    return mse, mae, r2

# %%
# Let's test multiple linear regression model we have learned so far including Ada Boost Regressor

models = {'Random Forest Classifier': RandomForestRegressor(), 'Linear Regression': LinearRegression(), 'Ridge': Ridge(), 'Lasso': Lasso(),
          'K Neighbors Regressor': KNeighborsRegressor(), 'Decision Tree Regressor': DecisionTreeRegressor(),
          'AdaBoost Regressor': AdaBoostRegressor()}

for k, v in models.items():
    model = v
    model.fit(X_train, y_train)

    # make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    mse_train, mae_train, r2_train = evaluate_model(y_train, y_train_pred)
    mse_test, mae_test, r2_test = evaluate_model(y_test, y_test_pred)

    print('===========================')
    print(k,':- Metrics')
    print('Train Model Performance Metrics ')
    print(f'root_mean_squared_error:- {mse_train}')
    print(f'mean_absolute_error:- {mae_train}')
    print(f'r2_score:- {r2_train}')

    print('-------------------')

    print('Test Model Performance Metrics ')
    print(f'root_mean_squared_error:- {mse_test}')
    print(f'mean_absolute_error:- {mae_test}')
    print(f'r2_score:- {r2_test}')

    print('\n')
# Out:
# ===========================
# Random Forest Classifier :- Metrics
# Train Model Performance Metrics
# root_mean_squared_error:- 18122008727.16762
# mean_absolute_error:- 39777.89371942634
# r2_score:- 0.9776556948724084
# -------------------
# Test Model Performance Metrics
# root_mean_squared_error:- 53308416398.86269
# mean_absolute_error:- 102153.32056055272
# r2_score:- 0.9291847689824642
#
#
# ===========================
# Linear Regression :- Metrics
# Train Model Performance Metrics
# root_mean_squared_error:- 306756099359.7596
# mean_absolute_error:- 268101.6070829937
# r2_score:- 0.6217719576765959
# -------------------
# Test Model Performance Metrics
# root_mean_squared_error:- 252550062888.5656
# mean_absolute_error:- 279618.57941584283
# r2_score:- 0.6645109298852004
#
#
# ===========================
# Ridge :- Metrics
# Train Model Performance Metrics
# root_mean_squared_error:- 306756818740.9266
# mean_absolute_error:- 268059.8014688303
# r2_score:- 0.6217710706848424
# -------------------
# Test Model Performance Metrics
# root_mean_squared_error:- 252540243247.9684
# mean_absolute_error:- 279557.2168930266
# r2_score:- 0.6645239743566812
#
#
# ===========================
# Lasso :- Metrics
# Train Model Performance Metrics
# root_mean_squared_error:- 306756104248.3742
# mean_absolute_error:- 268099.2226498116
# r2_score:- 0.6217719516489697
# -------------------
# Test Model Performance Metrics
# root_mean_squared_error:- 252549134806.78137
# mean_absolute_error:- 279614.74610341265
# r2_score:- 0.6645121627547995
#
#
# ===========================
# K Neighbors Regressor :- Metrics
# Train Model Performance Metrics
# root_mean_squared_error:- 106198764065.54185
# mean_absolute_error:- 91396.70668397145
# r2_score:- 0.8690576953041536
# -------------------
# Test Model Performance Metrics
# root_mean_squared_error:- 64079155016.42069
# mean_absolute_error:- 112578.24359390205
# r2_score:- 0.9148768529917701
#
#
# ===========================
# Decision Tree Regressor :- Metrics
# Train Model Performance Metrics
# root_mean_squared_error:- 432524990.53644824
# mean_absolute_error:- 5164.819922128488
# r2_score:- 0.9994666998284044
# -------------------
# Test Model Performance Metrics
# root_mean_squared_error:- 94750266586.23006
# mean_absolute_error:- 125498.45118391178
# r2_score:- 0.8741331581288516
#
#
# ===========================
# AdaBoost Regressor :- Metrics
# Train Model Performance Metrics
# root_mean_squared_error:- 208332887675.22235
# mean_absolute_error:- 352406.9273030492
# r2_score:- 0.7431270627660169
# -------------------
# Test Model Performance Metrics
# root_mean_squared_error:- 241274256781.49472
# mean_absolute_error:- 369549.0558069367
# r2_score:- 0.6794897806619082

# %%
# Let's fine tune Ada Boost, Randforest and K Neighbor models with some parameters and see if we can improve performance

knn_params = {'n_neighbors': [2,3,10,20,40,50]}
rf_params = {'max_depth': [None, 5,8,10, 15], 'max_features': [5,7,8, 'auto'], 'min_samples_split': [2,8,15,20], 'n_estimators': [100, 200, 500, 1000]}
ada_params = {'n_estimators': [50, 60, 70, 80], 'loss': ['linear', 'square', 'exponential']}

# %%
random_cv_model = [('KNN', KNeighborsRegressor(), knn_params), 
                   ('RF', RandomForestRegressor(), rf_params), 
                   ('ABR', AdaBoostRegressor(), ada_params)]

# %%
# Initialize and fit models with hyperparameters
model_best_param = {}

for name, model, params in random_cv_model:
    random = RandomizedSearchCV(estimator=model, param_distributions=params, n_iter=100, cv=3, verbose=2, n_jobs=-1)
    random.fit(X_train, y_train)
    model_best_param[name] = random.best_params_

for k, v in model_best_param.items():
    print(f'--------Best Params For Model {k} ------------')
    print(v)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV] END ......................................n_neighbors=2; total time=   0.6s
# [CV] END ......................................n_neighbors=2; total time=   0.6s
# [CV] END ......................................n_neighbors=2; total time=   0.6s
# [CV] END ......................................n_neighbors=3; total time=   0.7s
# [CV] END ......................................n_neighbors=3; total time=   0.7s
# [CV] END ......................................n_neighbors=3; total time=   0.8s
# [CV] END .....................................n_neighbors=10; total time=   1.2s
# [CV] END .....................................n_neighbors=10; total time=   1.2s
# [CV] END .....................................n_neighbors=10; total time=   1.3s
# [CV] END .....................................n_neighbors=20; total time=   1.6s
# [CV] END .....................................n_neighbors=20; total time=   1.6s
# [CV] END .....................................n_neighbors=20; total time=   1.7s
# [CV] END .....................................n_neighbors=40; total time=   1.6s
# [CV] END .....................................n_neighbors=40; total time=   1.6s
# [CV] END .....................................n_neighbors=40; total time=   1.6s
# [CV] END .....................................n_neighbors=50; total time=   1.6s
# [CV] END .....................................n_neighbors=50; total time=   1.6s
# [CV] END .....................................n_neighbors=50; total time=   1.6s
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   3.3s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=200; total time=   4.6s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=200; total time=   4.8s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=200; total time=   4.8s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=  10.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=  10.8s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=  10.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=500; total time=  14.4s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=500; total time=  14.5s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=500; total time=  14.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=  20.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=  21.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=  21.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=100; total time=   3.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=100; total time=   3.6s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=100; total time=   3.7s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=500; total time=  22.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=500; total time=  22.5s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=500; total time=  22.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=  18.9s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=  19.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=  19.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=  14.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=  14.1s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=  14.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   5.6s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   5.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   5.7s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=200; total time=  19.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=200; total time=  19.8s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=200; total time=  20.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=200; total time=  18.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=200; total time=  18.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=200; total time=  18.0s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=1000; total time=  43.9s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=1000; total time=  43.7s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=1000; total time=  43.6s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=500; total time=  36.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=500; total time=  36.4s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=500; total time=  36.8s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=100; total time=   3.6s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=100; total time=   3.6s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=100; total time=   3.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=500; total time=  15.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=500; total time=  15.3s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=500; total time=  15.3s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=200; total time=   2.5s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=200; total time=   2.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=200; total time=   2.5s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=100; total time=   3.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=100; total time=   4.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=100; total time=   3.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=1000; total time=  35.7s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=1000; total time=  36.2s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=1000; total time=  35.7s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   5.6s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=100; total time=   4.5s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   5.6s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   5.6s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=100; total time=   4.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=100; total time=   4.5s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=500; total time=   7.8s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=500; total time=   7.8s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=500; total time=   7.7s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=1000; total time=  24.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=1000; total time=  24.1s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=1000; total time=  24.1s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=200; total time=   6.6s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=200; total time=   6.6s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=200; total time=   6.6s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=500; total time=  12.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=500; total time=  13.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=500; total time=  13.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=200; total time=   7.3s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=200; total time=   7.3s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=200; total time=   7.3s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=100; total time=   3.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=100; total time=   3.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=100; total time=   3.1s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=100; total time=   2.1s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=100; total time=   2.1s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=100; total time=   2.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   7.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   7.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   7.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=1000; total time=  23.6s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=1000; total time=  23.6s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=1000; total time=  23.7s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=1000; total time=  29.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=1000; total time=  29.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=1000; total time=  29.2s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   2.8s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   2.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   2.9s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=1000; total time=  21.7s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=1000; total time=  22.1s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=1000; total time=  22.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.6s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=200; total time=   5.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=200; total time=   5.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=200; total time=   5.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=200; total time=   3.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=200; total time=   3.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=500; total time=  17.3s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=500; total time=  17.6s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=500; total time=  17.6s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=100; total time=   1.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=100; total time=   1.8s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=100; total time=   1.8s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=500; total time=  12.6s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=500; total time=  12.6s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=200; total time=   4.7s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=200; total time=   4.7s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=500; total time=  12.7s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=200; total time=   4.7s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=1000; total time=  29.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=1000; total time=  29.7s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=1000; total time=  29.9s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=  14.4s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=100; total time=   3.5s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=  14.3s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=100; total time=   3.4s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=  14.4s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=100; total time=   3.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=500; total time=  16.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=500; total time=  16.5s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=500; total time=  16.6s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=  19.6s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=  19.7s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=  19.7s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=1000; total time=  28.7s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=1000; total time=  28.6s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=1000; total time=  28.6s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=500; total time=  13.4s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=500; total time=  13.6s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=500; total time=  13.5s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=100; total time=   2.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=1000; total time=  36.6s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=100; total time=   2.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=1000; total time=  37.8s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=1000; total time=  37.9s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=500; total time=  15.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=500; total time=  15.1s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=500; total time=  15.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=  12.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=  12.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=  12.4s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=200; total time=   5.3s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=200; total time=   5.4s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=200; total time=   5.4s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=200; total time=   6.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=200; total time=   7.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=200; total time=   7.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=100; total time=   3.7s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=100; total time=   3.6s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=100; total time=   3.5s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   2.5s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   2.5s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   2.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=100; total time=   2.2s
# [CV] END max_depth=8, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=100; total time=   2.2s
# [CV] END max_depth=8, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=100; total time=   2.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=1000; total time=  14.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=1000; total time=  14.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=1000; total time=  14.7s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=500; total time=  10.4s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=500; total time=  10.4s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=500; total time=  10.3s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=200; total time=   5.0s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=200; total time=   5.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=200; total time=   5.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=1000; total time=  37.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=1000; total time=  37.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=1000; total time=  38.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=1000; total time=  35.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=1000; total time=  36.2s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=1000; total time=  36.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=1000; total time=  37.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=1000; total time=  37.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=1000; total time=  37.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=500; total time=  20.6s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=500; total time=  20.6s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=500; total time=  20.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=1000; total time=  27.7s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=1000; total time=  20.5s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=1000; total time=  27.6s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=1000; total time=  20.5s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=1000; total time=  20.6s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=1000; total time=  28.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   4.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   4.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   4.2s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=200; total time=   8.2s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=200; total time=   8.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=200; total time=   8.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=500; total time=  13.1s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=500; total time=  13.1s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=500; total time=  13.1s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=1000; total time=  28.6s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=1000; total time=  28.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=  46.7s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=1000; total time=  28.7s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=  46.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=  46.9s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   7.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   7.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   7.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=500; total time=   6.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=500; total time=   6.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=500; total time=   6.1s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=1000; total time=  25.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=1000; total time=  25.9s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=1000; total time=  25.6s
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END .......................loss=linear, n_estimators=50; total time=   0.4s
# [CV] END .......................loss=linear, n_estimators=80; total time=   0.5s
# [CV] END .......................loss=linear, n_estimators=70; total time=   0.6s
# [CV] END .......................loss=linear, n_estimators=50; total time=   0.6s
# [CV] END .......................loss=linear, n_estimators=60; total time=   0.7s
# [CV] END .......................loss=linear, n_estimators=70; total time=   0.8s
# [CV] END .......................loss=linear, n_estimators=80; total time=   0.8s
# [CV] END .......................loss=linear, n_estimators=50; total time=   1.1s
# [CV] END .......................loss=linear, n_estimators=60; total time=   1.2s
# [CV] END .......................loss=linear, n_estimators=60; total time=   1.3s
# [CV] END .......................loss=square, n_estimators=50; total time=   1.0s
# [CV] END .......................loss=linear, n_estimators=70; total time=   1.4s
# [CV] END .......................loss=square, n_estimators=50; total time=   1.0s
# [CV] END .......................loss=square, n_estimators=50; total time=   1.0s
# [CV] END .......................loss=linear, n_estimators=80; total time=   1.6s
# [CV] END .......................loss=square, n_estimators=60; total time=   1.1s
# [CV] END .......................loss=square, n_estimators=60; total time=   1.1s
# [CV] END .......................loss=square, n_estimators=60; total time=   1.1s
# [CV] END .......................loss=square, n_estimators=70; total time=   1.3s
# [CV] END .......................loss=square, n_estimators=70; total time=   1.3s
# [CV] END .......................loss=square, n_estimators=70; total time=   1.3s
# [CV] END ..................loss=exponential, n_estimators=50; total time=   1.1s
# [CV] END ..................loss=exponential, n_estimators=50; total time=   1.0s
# [CV] END ..................loss=exponential, n_estimators=50; total time=   1.1s
# [CV] END .......................loss=square, n_estimators=80; total time=   1.5s
# [CV] END .......................loss=square, n_estimators=80; total time=   1.5s
# [CV] END .......................loss=square, n_estimators=80; total time=   1.5s
# [CV] END ..................loss=exponential, n_estimators=60; total time=   1.2s
# [CV] END ..................loss=exponential, n_estimators=60; total time=   1.2s
# [CV] END ..................loss=exponential, n_estimators=60; total time=   1.2s
# [CV] END ..................loss=exponential, n_estimators=70; total time=   1.3s
# [CV] END ..................loss=exponential, n_estimators=70; total time=   1.2s
# [CV] END ..................loss=exponential, n_estimators=70; total time=   1.2s
# [CV] END ..................loss=exponential, n_estimators=80; total time=   1.2s
# [CV] END ..................loss=exponential, n_estimators=80; total time=   1.3s
# [CV] END ..................loss=exponential, n_estimators=80; total time=   1.2s
# --------Best Params For Model KNN ------------
# {'n_neighbors': 10}
# --------Best Params For Model RF ------------
# {'n_estimators': 500, 'min_samples_split': 2, 'max_features': 7, 'max_depth': 15}
# --------Best Params For Model ABR ------------
# {'n_estimators': 50, 'loss': 'linear'}

# %%
# let's retrain our models with best params

models = {'Random Forest Classifier': RandomForestRegressor(n_estimators=model_best_param['RF']['n_estimators'],
                                                              min_samples_split=model_best_param['RF']['min_samples_split'], 
                                                              max_features=model_best_param['RF']['max_features'], 
                                                              max_depth=model_best_param['RF']['max_depth'], n_jobs=-1),
          'K Neighbors Regressor': KNeighborsRegressor(n_neighbors=model_best_param['KNN']['n_neighbors'], n_jobs=-1),
          'Ada Boost Regressor': AdaBoostRegressor(n_estimators=model_best_param['ABR']['n_estimators'], loss=model_best_param['ABR']['loss'])}

for k, v in models.items():
    model = v
    model.fit(X_train, y_train)

    # make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    mse_train, mae_train, r2_train = evaluate_model(y_train, y_train_pred)
    mse_test, mae_test, r2_test = evaluate_model(y_test, y_test_pred)

    print('===========================')
    print(k,':- Metrics')
    print('Train Model Performance Metrics ')
    print(f'root_mean_squared_error:- {mse_train}')
    print(f'mean_absolute_error:- {mae_train}')
    print(f'r2_score:- {r2_train}')

    print('-------------------')

    print('Test Model Performance Metrics ')
    print(f'root_mean_squared_error:- {mse_test}')
    print(f'mean_absolute_error:- {mae_test}')
    print(f'r2_score:- {r2_test}')

    print('\n')
# Out:
# ===========================
# Random Forest Classifier :- Metrics
# Train Model Performance Metrics
# root_mean_squared_error:- 17831258303.03673
# mean_absolute_error:- 54309.57360552506
# r2_score:- 0.9780141880334352
# -------------------
# Test Model Performance Metrics
# root_mean_squared_error:- 45075116444.16337
# mean_absolute_error:- 97064.20617119741
# r2_score:- 0.9401219357136286
#
#
# ===========================
# K Neighbors Regressor :- Metrics
# Train Model Performance Metrics
# root_mean_squared_error:- 132092099887.24854
# mean_absolute_error:- 103456.64341336794
# r2_score:- 0.8371314003176575
# -------------------
# Test Model Performance Metrics
# root_mean_squared_error:- 69620968665.46384
# mean_absolute_error:- 117432.89815115147
# r2_score:- 0.9075150733643885
#
#
# ===========================
# Ada Boost Regressor :- Metrics
# Train Model Performance Metrics
# root_mean_squared_error:- 237992317651.4148
# mean_absolute_error:- 379753.6388850271
# r2_score:- 0.7065572010428537
# -------------------
# Test Model Performance Metrics
# root_mean_squared_error:- 269259161268.40115
# mean_absolute_error:- 396914.03214638564
# r2_score:- 0.64231445995052
